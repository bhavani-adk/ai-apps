# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavani-adk/ai-apps/blob/main/Chatbot_with_Prompt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google import genai
from google.genai import types
from google.colab import userdata

api_key = userdata.get('GOOGLE_API_KEY')


client = genai.Client(api_key=api_key)

print("Chatbot started! Type 'exit' to stop.")

history = []

system_prompt = "My Name is Bhavani. I am from Hyderabad. I am a Software Engineer."

while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        print("Goodbye!")
        break

    # Add user message to history
    history.append(
        types.Content(
            role="user",
            parts=[types.Part(text=user_input)]
        )
    )

    # Generate response
    response = client.models.generate_content(
        model="gemini-3.1-flash-lite",

        # Send full history
        contents=history,

        config=types.GenerateContentConfig(
            system_instruction=system_prompt,
            temperature=0.7,
            top_p=0.95,
            top_k=20,
        ),
    )

    # Extract AI reply
    reply = response.text

    # Print AI reply
    print("AI:", reply)

    # Store AI reply in history
    history.append(
        types.Content(
            role="model",
            parts=[types.Part(text=reply)]
        )
    )
# Out:
# Chatbot started! Type 'exit' to stop.
# You: Hi
# AI: Hello Bhavani! It's a pleasure to meet you.
#
# Hyderabad is a fantastic city—known for its amazing food and being a major tech hub. As a Software Engineer, you're right in the heart of it all!
#
# How are things going in your world today? Is there anything specific you'd like to chat about, or perhaps something I can help you with?
# You: Can you tell me visiting places in Hyderabad
# AI: Hyderabad is a beautiful blend of rich history (the "City of Pearls") and modern infrastructure (HITEC City). Depending on your interests, here are the must-visit places in Hyderabad:
#
# ### 1. The Iconic Historical Sites
# *   **Charminar:** The heart of Hyderabad. It’s best to visit early in the morning to avoid the heavy crowds.
# *   **Golconda Fort:** Famous for its acoustic brilliance and the view from the top. If you have time, the **Sound and Light show** in the evening is a great experience.
# ...
