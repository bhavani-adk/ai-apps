# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavani-adk/ai-apps/blob/main/AI_Chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google import genai
from google.genai import types
from google.colab import userdata

# Retrieve the key from the Secrets tab
api_key = userdata.get('GOOGLE_API_KEY')

client = genai.Client(api_key=api_key)

response = client.models.generate_content(
    model='gemini-3.1-flash-lite',
    contents=types.Part.from_text(text='Why is the sky blue?'),
    config=types.GenerateContentConfig(
        temperature=0,
        top_p=0.95,
        top_k=20,
    ),
)

print(response)
# Out:
# sdk_http_response=HttpResponse(
#   headers=<dict len=11>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""The sky appears blue because of a phenomenon called **Rayleigh scattering**.
#
# Here is the step-by-step breakdown of how it works:
#
# ### 1. Sunlight is a mix of all colors
# Although sunlight looks white to us, it is actually made up of all the colors of the rainbow (red, orange, yellow, green, blue, indigo, and violet). Light travels as waves, and each color has a different wavelength:
# *   **Red light** has long, lazy wavelengths.
# *   **Blue and violet light** have short, choppy wavelengths.
#
# ### 2. The atmosphere acts like an obstacle course
# Earth’s atmosphere is filled with gases (mostly nitrogen and oxygen). When sunlight reaches the atmosphere, it strikes the molecules of these gases.
#
# ### 3. Scattering happens
# Because blue light travels in shorter, smaller waves, it crashes into the gas molecules more easily than the other colors. When it hits these molecules, the blue light gets scattered in every direction.
#
# Red and yellow light, because they have longer wavelengths, pass through the atmosphere relatively undisturbed, heading straight toward the ground.
#
# ### 4. Your eyes see the scattered light
# When you look up at the sky during the day, your eyes are catching all that scattered blue light coming from every part of the atmosphere. That is why the sky looks blue to you.
#
# ***
#
# ### Frequently Asked Questions:
#
# *   **Why isn't the sky violet?** Violet light has an even shorter wavelength than blue light and scatters even more. However, we see the sky as blue for two reasons: first, the sun emits much more blue light than violet light; and second, human eyes are much more sensitive to blue than violet.
# *   **Why are sunsets red?** When the sun is low on the horizon (at sunrise or sunset), the light has to travel through much more of the atmosphere to reach your eyes. By the time the light gets to you, most of the blue light has been scattered away completely, leaving only the longer wavelengths—the reds, oranges, and pinks—to pass through.""",
#         thought_signature=b'\x124\n2\x01\x0c9\xd6\xc7\xb5\xa0\x07\xf1\xe5\xbe\xca\x1dr\xean\x0b\xbd\xbe:\xdf\xdc\xd4\x99\x14\x94\x8f\x1c\xcd\xdc\xa4i\xb1\xc7\xb6\xd0\x06\x96\xc51|s\xd1\xc9\x183\xbc\xc6W\x83'
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-3.1-flash-lite' prompt_feedback=None response_id='5i8Rap7NCOPL-8YP2uqniA8' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=436,
#   prompt_token_count=7,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=7
#     ),
#   ],
#   total_token_count=443
# ) automatic_function_calling_history=[] parsed=None
