# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavani-adk/ai-apps/blob/main/Email_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google import genai
from google.colab import userdata

# Get API Key from Colab Secrets
API_KEY = userdata.get("GOOGLE_API_KEY")

# Initialize Gemini Client
client = genai.Client(api_key=API_KEY)

print("=== AI Email Generator ===")
print("Type 'exit' anytime to quit.\n")

while True:

    # Take user input
    user_request = input("What email do you want to write?\n> ")

    # Exit condition
    if user_request.lower() == "exit":
        print("Program closed.")
        break

    # Generate response using Gemini
    response = client.models.generate_content(
        model='gemini-3.1-flash-lite',

        contents=(
            "You are a professional email writer. "
            "Write clear, professional, polite emails.\n\n"
            f"User Request: {user_request}"
        )
    )

    # Extract AI response
    email = response.text

    # Print generated email
    print("\n========== GENERATED EMAIL ==========\n")
    print(email)
    print("\n=====================================\n")
# Out:
# === AI Email Generator ===
# Type 'exit' anytime to quit.
#
# What email do you want to write?
# > Sick Leave
#
# ========== GENERATED EMAIL ==========
#
# To provide you with the best email, I have drafted three versions depending on your specific situation. Choose the one that best fits your needs.
#
# ### Option 1: Standard (Clear and concise)
# **Subject:** Sick Leave Notification - [Your Name]
#
# Dear [Manager's Name],
#
# Please accept this email as notification that I am unable to attend work today, [Date], due to illness.
#
# I plan to monitor my emails periodically, but please expect a delay in my response. I hope to be back in the office by [Date you expect to return].
#
# Thank you for your understanding.
#
# Best regards,
#
# [Your Name]
#
# ***
#
# ### Option 2: If you need to delegate tasks (Professional & Proactive)
# **Subject:** Absence Today - [Your Name] - [Date]
#
# Hi [Manager's Name],
#
# ...
