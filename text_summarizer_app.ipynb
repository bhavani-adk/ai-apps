# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavani-adk/ai-apps/blob/main/text_summarizer_app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google import genai
from google.genai import types
from google.colab import userdata

# Retrieve the key from the Secrets tab
api_key = userdata.get('GOOGLE_API_KEY')

client = genai.Client(api_key=api_key)

text = input("Enter long text: ")

response = client.models.generate_content(
    model='gemini-3.1-flash-lite',
    contents=f"Summarize this:\n{text}",
    config={
        "system_instruction": "You are a helpful assistant that summarizes text."
    }
)

print("\nSummary:")
print(response.text)
# Out:
# Enter long text: Rubio’s India itinerary, scheduled from May 23 to 26 and also encompassing Agra, Jaipur, and New Delhi, is being viewed as diplomatically significant for his scheduled energy talks with India and the meeting with Ministers from the Quad nations.
#
# Summary:
# Rubio’s visit to India (May 23–26) is considered diplomatically significant, as he is set to hold energy talks and meet with ministers from the Quad nations.
